# %%
print("Hello World")
# Out:
# Hello World

# %%
import sys
print(sys.version)
# Out:
# 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)]

# %%
print("Hello, I am Ansh Raj")
# Out:
# Hello, I am Ansh Raj

# %%
x = 10
y = 20
x,y = y,x
print(x, y)
# Out:
# 20 10

# %%
i = 10
j = i + 7
print(id(i))
print(id(j))
# Out:
# 2252567964240
# 2252567964464

# %%
x = 4
y = x
print(x)
print(y)
# Out:
# 4
# 4
